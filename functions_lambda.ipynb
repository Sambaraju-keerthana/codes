# %%
#User defined functions in python

#defining function
def my_function():
  print("Hello from a function")
#To call a function use function name followed by parenthesis
my_function()
# Out:
# Hello from a function

# %%
#User defined fuction with arguments
def my_function(fname, lname):
  print(fname + " " + lname)

my_function("Python", "Program")

# %%
#arbitrary arguments
def my_function(*Dept):
  print("The Department is " + Dept[2])

my_function("MCA", "MBA", "Mtech")

# %%
#Keyword Arguments
def my_function(dept3, dept2, dept1):
  print("The department  is " + dept3)

my_function(dept1 = "MCA", dept2 = "MBA", dept3 = "Mtech")

# %%
#Default Parameter value
def my_function(country = "India"):
  print("I am from " + country)

my_function("Sweden")
my_function("Norway")
my_function()
my_function("Brazil")

# %%
#Arbitrary Keyword Arguments, **kwargs
def my_function(**person):
  print("His last name is " + person["lname"])

my_function(fname="XYZ", lname="ABC")
# Out:
# His last name is ABC

# %%
#Passing a List as an Argument
def my_function(Dept):
  for x in Dept:
    print(x)

Dept = ["MCA", "MBA", "Mtech"]

my_function(Dept)
# Out:
# MCA
# MBA
# Mtech

# %%
'''
A lambda function is a special type of function without the function name.
Use the lambda keyword instead of def to create a lambda function.
A lambda function is a small anonymous function.

A lambda function can take any number of arguments, but can only have one 
expression
Use lambda functions when an anonymous function is required for short period 
of time
Here's the syntax to declare the lambda function

lambda argument(s) : expression 
'''
#Add 10 to argument a, and return the result
x = lambda a : a + 10
print(x(5))
x = lambda a, b : a * b
print(x(5, 6))
x = lambda a, b, c : a + b + c
print(x(5, 6, 2))
# Out:
# 15
# 30
# 13

# %%
#The power of lambda is better,when you use them as an anonymous function
#inside another function
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)

print(mydoubler(11))
#Or,use the same function definition to make both functions,in the same program
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)
mytripler = myfunc(3)

print(mydoubler(11))
print(mytripler(11))
# Out:
# 22
# 22
# 33

# %%
# Program to double each item in a list using map()

my_list = [1, 5, 4, 6, 8, 11, 3, 12]

new_list = list(map(lambda x: x * 2 , my_list))


print(new_list)
# Out:
# [2, 10, 8, 12, 16, 22, 6, 24]
