# %%
import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.probability import FreqDist
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
nltk.download('punkt')
nltk.downloadhttp://localhost:8888/notebooks/wordcloud.ipynb#('stopwards')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /home/dsbatch2/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Error loading stopwards: Package 'stopwards' not found in
# [nltk_data]     index
# [nltk_data] Downloading package wordnet to /home/dsbatch2/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/dsbatch2/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
data =open('Downloads/output.txt','r').read()

# %%
sentences = sent_tokenize(data)
words = word_tokenize(data)

# %%
len(data)
# Out:
# 439826

# %%
words=[word.lower() for word in words if word.isalpha()]

# %%
stop_words =set(stopwords.words('english'))
filtered_words=[word for word in words if word not in stop_words]

# %%
len(stop_words)
# Out:
# 198

# %%
stemmer =PorterStemmer()
stemmed_words=[stemmer.stem(word)for word in filtered_words]
lemmatizer=WordNetLemmatizer()
lemmatized_words=[lemmatizer.lemmatize(word)for word in filtered_words]
processed_text = ' '.join(lemmatized_words)

# %%
len(processed_text)
# Out:
# 253140

# %%
words =nltk.word_tokenize(processed_text)
word_freq=nltk.FreqDist(words)
top_words=word_freq.most_common(40)

# %%
top_words
# Out:
# [('said', 738),
#  ('poirot', 615),
#  ('one', 384),
#  ('linnet', 306),
#  ('doyle', 304),
#  ('yes', 263),
#  ('race', 255),
#  ('miss', 254),
#  ('simon', 248),
#  ('would', 232),
#  ('know', 231),
#  ('think', 228),
#  ('like', 183),
#  ('man', 180),
#  ('cabin', 175),
#  ('see', 174),
#  ('say', 172),
#  ('got', 171),
#  ('looked', 169),
#  ('went', 169),
#  ('little', 167),
#  ('thing', 159),
#  ('head', 157),
#  ('allerton', 150),
#  ('jacqueline', 149),
#  ('could', 147),
#  ('cornelia', 147),
#  ('tim', 144),
#  ('well', 143),
#  ('pennington', 141),
#  ('two', 139),
#  ('go', 137),
#  ('quite', 132),
#  ('came', 125),
#  ('time', 124),
#  ('girl', 121),
#  ('come', 116),
#  ('face', 115),
#  ('de', 114),
#  ('fanthorp', 113)]

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np

# %%
pip install --upgrade wordcloud pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.2/526.2 KB 587.0 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 158.2 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#   Attempting uninstall: wordcloud
#     Found existing installation: wordcloud 1.9.4
#     Uninstalling wordcloud-1.9.4:
#       Successfully uninstalled wordcloud-1.9.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
wordcloud=WordCloud(width=1000,height =500,random_state=1,background_color='#0A1B27',colormap='Pastel1',collocations=False,stopwords=STOPWORDS).generate_from_frequencies(dict(top_words))
plt.figure(figsize =(20,15))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %%
car_mask =np.array(Image.open("Downloads/cloud2.jpeg"))

# %%
car_mask=255-car_mask

# %%
img=WordCloud(width=1000,height =500,random_state=1,mask=car_mask,colormap='Pastel1',collocations =False,stopwords=STOPWORDS, background_color='rgba(0,0,0,0)',mode='RGBA').generate_from_frequencies(dict(top_words))
plt.figure(figsize =(10,15))
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 318.5, 157.5, -0.5)
